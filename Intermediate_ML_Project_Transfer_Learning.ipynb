# %%
# Intermediate Machine Learning Project
## Image Classification using Transfer Learning
### MobileNetV2 + TensorFlow/Keras

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.20.0

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content

# %%
import os

os.makedirs("/content/food_dataset/train", exist_ok=True)
os.makedirs("/content/food_dataset/validation", exist_ok=True)
os.makedirs("/content/food_dataset/test", exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
# !pip install -q datasets

# %%
import datasets

print("Datasets library installed successfully!")
# Out:
# Datasets library installed successfully!

# %%
from datasets import load_dataset

dataset = load_dataset("rajistics/indian_food_images")

print(dataset)
# Out:
# README.md:   0%|          | 0.00/660 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# dataset_infos.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# data/train-00000-of-00001-dbae6752a5d31c(…): reconstructing file:   0%|          |  0.00B / 1.36GB
# data/train-00000-of-00001-dbae6752a5d31c(…): downloading bytes:           |  0.00B
# data/test-00000-of-00001-899c7c7e401d279(…): reconstructing file:   0%|          |  0.00B /  241MB
# data/test-00000-of-00001-899c7c7e401d279(…): downloading bytes:           |  0.00B
# ...
# Generating test split:   0%|          | 0/941 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 5328
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 941
#     })
# })

# %%
print(dataset["train"].features)
# Out:
# {'image': Image(mode=None, decode=True), 'label': ClassLabel(names=['burger', 'butter_naan', 'chai', 'chapati', 'chole_bhature', 'dal_makhani', 'dhokla', 'fried_rice', 'idli', 'jalebi', 'kaathi_rolls', 'kadai_paneer', 'kulfi', 'masala_dosa', 'momos', 'paani_puri', 'pakode', 'pav_bhaji', 'pizza', 'samosa'])}

# %%
import matplotlib.pyplot as plt

sample = dataset["train"][0]

plt.imshow(sample["image"])
plt.title(sample["label"])
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 3, figsize=(12, 8))

for i, ax in enumerate(axes.flat):
    sample = dataset["train"][i]
    ax.imshow(sample["image"])
    ax.set_title(sample["label"])
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
from collections import Counter

label_counts = Counter(dataset["train"]["label"])

print(label_counts)
# Out:
# Counter({11: 358, 4: 357, 3: 346, 2: 324, 7: 311, 17: 311, 1: 276, 14: 270, 5: 266, 13: 264, 8: 263, 9: 259, 0: 257, 10: 249, 6: 236, 16: 231, 18: 224, 19: 218, 12: 196, 15: 112})

# %%
len(dataset["train"])
# Out:
# 5328

# %%
# Day 1 - Intermediate Project: Dataset Exploration & Setup

### Completed:
- TensorFlow and required libraries setup
- GPU verification
- Food image dataset loaded
- 6,269 total images identified
- 20 food classes identified
- Sample images visualized
- Class distribution analyzed
- Training dataset size verified: 5,328 images

### Day 1 Status: Completed ✅
